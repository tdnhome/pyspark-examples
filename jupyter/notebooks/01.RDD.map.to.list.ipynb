# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
sc = spark.sparkContext

# Read input
data = [1, 4, 7]
distData = sc.parallelize(data)

# Print the input
print()
print ("INPUT:")
results = distData.collect()
for result in results:
    print (result)

# Select rows 
mapToList = distData.map(lambda x: [x, x+1, x+2])

# Collect and print the results
print
print ("MAPPED: for evey input x, return a list of x, x+1, x+2")
results = mapToList.collect()
for result in results:
    print (result)
# Out:
# INPUT:
# 1
# 4
# 7
# MAPPED: for evey input x, return a list of x, x+1, x+2
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
