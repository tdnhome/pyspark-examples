# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
sc = spark.sparkContext

# For each input line (normally from the CVS file), extract the
# age and numFriend fields and return a tuple (age, numFriends)
def parseLine(line):
    fields = line.split(',')
    age = int(fields[2])
    numFriends = int(fields[3])
    return (age, numFriends)

# Read all data into collection of line
lines = sc.textFile("fakefriends_small.csv")

# Map data into key/value pairs (age, numFriends)
pairRDD = lines.map(parseLine)
results = ageToNumFriends.collect()
print ("(age, # of friends)")
for result in results:
    print (result)

# Count by key: count number of occurence of age
ageCounts = ageToNumFriends.countByKey()

# Display the results which is a hashmap of (K, Int)
for age, count in ageCounts.items():
    print ('Number of occurence of age = {0} is {1}'.format(age, count))
# Out:
# (age, # of friends)
# (18, 385)
# (19, 2)
# (19, 221)
# (20, 465)
# (20, 21)
# (20, 318)
# (21, 220)
# (21, 307)
# (21, 380)
# (21, 181)
# Number of occurence of age = 18 is 1
# Number of occurence of age = 19 is 2
# Number of occurence of age = 20 is 3
# Number of occurence of age = 21 is 4
