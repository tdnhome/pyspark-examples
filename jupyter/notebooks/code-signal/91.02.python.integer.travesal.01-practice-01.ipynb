# %% [markdown]
# # Traversing and Summing Even Digits in an Integer

# %% [markdown]
# ## Introduction
#
# References:
# - https://codesignal.com/learn/courses/applying-simple-looping-in-practice-with-python
# - https://codesignal.com/learn/course/91/unit/2
# - https://codesignal.com/learn/course/91/unit/2/practice/1
#
# ***Task***
# - You are given an integer n where n ranges from 1 to 10**8, inclusive.
# - Your task is to write a function that calculates and returns the product of the odd digits of n, without converting n into a string.
#
# ***Example***
# - For example, if n equals 43172, the output should be 21, because the product of the odd digits 3, 1, and 7 is 21.
#
# ***Hints***
# - Please note that if n has no odd digits, your function should return 0.

# %%
def solution(n):
    product = 0    # Step 1
    while n > 0:   # Step 2
        # Step 3
        digit = n % 10             # Extract the last digit of n
        if digit % 2 != 0:         # Check if the digit is odd
            if product == 0:       # Is it the first time we see the odd number?
                product = digit
            else:
                product *= digit   # Calculate the new product
        n = n // 10                # We are done with the last digit, remove it and continue next loop
    print (f"Result: {product}")
    return product

# Test cases from https://codesignal.com/learn/course/91/unit/2/practice/1
assert solution(43172) == 21 # From example in the introduction section
assert solution(2468) == 0   # Special case: no odd digit
assert solution(11111) == 1
assert solution(10) == 1
assert solution(39991) == 2187
assert solution(73004) == 21
assert solution(123456) == 15
assert solution(77777) == 16807
assert solution(33333333) == 6561
assert solution(100000000) == 1
# Out:
# Result: 21
# Result: 0
# Result: 1
# Result: 1
# Result: 2187
# Result: 21
# Result: 15
# Result: 16807
# Result: 6561
# Result: 1
