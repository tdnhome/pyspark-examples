# %% [markdown]
# # Looping Through Python Strings and Mastering Character Operations

# %% [markdown]
# ## Introduction
#
# References:
# - https://codesignal.com/learn/courses/revisiting-python-essentials
# - https://codesignal.com/learn/course/90/unit/5

# %% [markdown]
# What You'll Learn
#
# Our goal for this lesson is to learn about looping concepts in Python, with a specific focus on strings. We'll dive deep into string indexing techniques and gain experience performing character operations using Python’s built-in functions. Plus, we'll explore how to handle exceptions while performing these operations.

# %% [markdown]
# ## Looping Over Strings
#
# - In Python, a string is a sequence. When scraping a website, you might receive all the text as a single string.
# - Strings are sequences of characters, and
# - Python allows us to loop over these sequences using a for loop.
#
# On the example below, the for loop will print each character of the string on a new line, proving beneficial when you need to locate specific characters or words.

# %%
text = "Hello!"
for char in text:
    print(char)
# Out:
# H
# e
# l
# l
# o
# !

# %% [markdown]
# ## String Indexing Reminder
#
# - Python strings operate under a zero-based indexing system.
# - This setup means that we can access specific characters in the string merely by knowing their position
# - The try-except block helps us handle any IndexError, which can transpire when we attempt to access an index that doesn't exist in our string.

# %%
try:
    text = "Hello, Python!"
    tenth_char = text[9]
    print('The tenth character is:', tenth_char)
except IndexError as e:
    print("Char access error message:", e)
# Out:
# The tenth character is: t

# %% [markdown]
# ## Character Operations
#
# Python provides various built-in functions, such as ord(), chr(), upper(), lower(), and isalpha(). We'll consider how such functions can prove advantageous in real-world scenarios, like data cleaning, where one might need to standardize the case of the text data.
#
# Here are some illustrative examples:
#
# - The ord() and chr() functions could prove valuable when implementing encryption algorithms. Specifically, ord(c) returns an ASCII ordinal number of the provided character c, and chr(c) converts the provided ASCII ordinal number back to the character.
# - The upper() and lower() methods are useful when comparing strings irrespective of their case.
# - The isalpha(), isdigit(), and isalnum() methods are useful when you need to check whether the character or all letters in the string satisfy a specific condition (are all letters, all digits, or letters/digits, respectively).

# %%
print(ord('A'))  # Prints: 65
print(chr(65))   # Prints: 'A'
print(chr(ord('A') + 1)) # Prints: 'B'
# Out:
# 65
# A
# B

# %% [markdown]
# ## String Append Reminder
#
# - Python allows you to append to the string usine += operator

# %%
text = "Python is fun!"
cleaned_text = ""  # We will append the characters from the text above using += operator

for char in text:
    if char.islower():
        cleaned_text += char.upper()
    elif char.isupper():
        cleaned_text += char.lower()
    else:  # Keep non-alphabetical characters unchanged
        cleaned_text += char

print(cleaned_text)  # outputs: "pYTHON IS FUN!"
# Out:
# pYTHON IS FUN!

# %% [markdown]
# ## Lesson Summary
#
# Excellent work! We've learned how to work with strings by looping over them, referring to string indices, and manipulating characters using Python's built-in functions. Furthermore, we delved into strategies to handle errors that may occur when dealing with strings in our programs.
#
# The real world is full of tasks involving string operations. From building smart typewriters and web scrapers to AI bots, string operations will indeed prove to be a useful tool. Therefore, why wait? Get hands-on with the upcoming exercises. Your journey is just beginning! See you there!

# %% [markdown]
# # Practices
#
# References:
# https://codesignal.com/learn/course/90/unit/5/practice/1

# %% [markdown]
# ## https://codesignal.com/learn/course/90/unit/5/practice/1

# %% [markdown]
# - Your task is to tweak the given string manipulation code.
# - Modify the loop so that, instead of altering the letter cases, it counts the number of lowercase characters in the text.
# - Use the final print statement to display the count.

# %%
text = "Python is fun!"
lower_char_count = 0

for char in text:
    if char.islower():
        lower_char_count += 1
print(lower_char_count)
# Out:
# 10

# %% [markdown]
# ## https://codesignal.com/learn/course/90/unit/5/practice/2

# %% [markdown]
# - Below is a piece of code meant to process a string into uppercase (the code should process only the alphanumeric characters into an output string), but it has a small bug.
# - Your task is to identify and fix the issue.
# - Remember, characters must be letters before they are converted to uppercase.
#
# Note: the output of the code should not include characters that aren't letters.
#
# ***Hint: if char.isalpha:***
#
# - Without parentheses, Python treats str.isalpha as a reference to the function object itself rather than executing the actual check.
# - This is syntactically valid code, so it will not throw an error.
# - When you omit the parentheses, the code evaluates the function as a built-in method (which will always evaluate as True in a boolean context).
# - To actually execute the method and return True or False, you must add the parentheses str.isalpha()

# %%
def process_text(text):
    new_text = ""
    for char in text:
        if char.isalpha():
            new_text += char.upper()
    print(f"Processed Text: {new_text}")

process_text("Happy Coding,! Friends!")
# Out:
# Processed Text: HAPPYCODINGFRIENDS

# %% [markdown]
# ## https://codesignal.com/learn/course/90/unit/5/practice/3

# %% [markdown]
# Now, it's your turn to secure communication by encrypting a message.
#
# - Write a piece of code that shifts each letter in the provided text one position forward in the alphabet while keeping non-alphabetic characters unchanged.
#
# ***About the Caesar Cipher:***
#
# - The Caesar Cipher is a classic encryption technique that dates back to ancient Rome.
# - It works by shifting each letter in the plaintext by a fixed number of positions down the alphabet.
# - For example, with a shift of 3, a becomes d, b becomes e, and so on.
# - When the end of the alphabet is reached, the cipher "wraps around" so that x becomes a, y becomes b, and z becomes c.
# - Only alphabetic characters are shifted; all other characters (such as punctuation and spaces) remain unchanged.

# %%
def encrypt_string(text):
    encrypted = []
    for char in text:
        # TODO: Check if `char` is a letter different from 'z' and 'Z'. If so, increment by 1.
        # If 'char' is 'z', change it to 'a'. 
        # If 'char' is 'Z', change it to 'A'.
        # Otherwise, keep 'c' unchanged and add it to the encrypted list.
        if char == 'z':
            char = 'a'
        elif char == 'Z':
            char = 'A'
        elif char.isalpha():
            char = chr(ord(char) + 1)
        encrypted += char
    return ''.join(encrypted)

# Encrypt the string "Hello, Python!" by shifting each letter in the alphabet one by one.
print(encrypt_string("abyz1 ABYZ1"))
encrypted_text = encrypt_string("Hello, Python!")
print("The encrypted text is:", encrypted_text) # Should print out "Ifmmp, Qzuipo!"
# Out:
# bcza1 BCZA1
# The encrypted text is: Ifmmp, Qzuipo!

# %% [markdown]
# ## https://codesignal.com/learn/course/90/unit/5/practice/4

# %% [markdown]
# - In this challenge, you are tasked with implementing the encryption logic for the Caesar Cipher from scratch.
# - Your task is to update the placeholders to provide the correct ASCII values required to shift the characters within a string.
#
# ***About the Caesar Cipher:***
# - The Caesar Cipher is a classic encryption technique that dates back to ancient Rome.
# - It works by shifting each letter in the plaintext by a fixed number of positions down the alphabet.
# - For example, with a shift of 3, a becomes d, b becomes e, and so on.
# - When the end of the alphabet is reached, the cipher "wraps around" so that x becomes a, y becomes b, and z becomes c.
# - Only alphabetic characters are shifted; all other characters (such as punctuation and spaces) remain unchanged.

# %%
# A simple text encryption exercise using the Caesar Cipher technique.
# The Caesar Cipher for `shift = 3` cyclically shifts every letter of the word by 3 positions:
# a -> d, b -> e, c -> f, ..., x -> a, y -> b, z -> c

# Implement the encryption logic by shifting each alphabet character

def encrypt_text(text):
    encrypted = ""
    for char in text:
        if char.isalpha():  # check if the character is an alphabet
            shift = 3
            # TODO: Use the correct ASCII values to shift the character and add it to 'encrypted'
            encrypted += shift_char(char, shift)
            # Hint: You can use the modulo operator (%) to make the alphabet "wrap around" when shifting past 'z' or 'Z'.
            # Hint: Each letter has a unique ASCII value. For example, ord('A') = 65 and ord('a') = 97.
            # Hint: To shift a letter within the alphabet, first convert the character to its ASCII value.
            # Remember to handle both uppercase and lowercase letters.
        else:
            encrypted += char  # keep non-alphabet characters unchanged
    return encrypted

def shift_char(char, shift):
    base = ord('a') if char.islower() else ord('A')    
    # 1. Convert character to 0-25 index: ord(char) - base
    # 2. Add the shift and apply modulo 26: % 26
    # 3. Add back the base ASCII value to return to character form
    return chr((ord(char) - base + shift) % 26 + base)
    
# Example text to encrypt
original_text = "Hello, Python!"
# The encrypted_text function call and print statement should be the same as in the solution
encrypted_text = encrypt_text(original_text)
print(encrypted_text)  # The correct output after implementing the TODO should be 'Khoor, Sbwkrq!'
# Out:
# Khoor, Sbwkrq!

# %% [markdown]
# ## https://codesignal.com/learn/course/90/unit/5/practice/5

# %% [markdown]
# ***Task***:
# - Write a program that takes text and an integer as a shift value to encrypt it by shifting each letter by the shift value in the alphabet.
# - Non-alphabetic characters should remain the same.
#
# ***Hint***
# - Update the previous practice function, encrypt_text(), to accept the input shift value.

# %%
def encrypt_text(text, shift):
    encrypted = ""
    for char in text:
        if char.isalpha():  # check if the character is an alphabet
            # TODO: Use the correct ASCII values to shift the character and add it to 'encrypted'
            encrypted += shift_char(char, shift)
            # Hint: You can use the modulo operator (%) to make the alphabet "wrap around" when shifting past 'z' or 'Z'.
            # Hint: Each letter has a unique ASCII value. For example, ord('A') = 65 and ord('a') = 97.
            # Hint: To shift a letter within the alphabet, first convert the character to its ASCII value.
            # Remember to handle both uppercase and lowercase letters.
        else:
            encrypted += char  # keep non-alphabet characters unchanged
    return encrypted

def shift_char(char, shift):
    base = ord('a') if char.islower() else ord('A')    
    # 1. Convert character to 0-25 index: ord(char) - base
    # 2. Add the shift and apply modulo 26: % 26
    # 3. Add back the base ASCII value to return to character form
    return chr((ord(char) - base + shift) % 26 + base)
    
# Example text to encrypt
original_text = "Hello, Python!"
# The encrypted_text function call and print statement should be the same as in the solution
encrypted_text = encrypt_text(original_text, 3)
print(encrypted_text)  # The correct output after implementing the TODO should be 'Khoor, Sbwkrq!'
# Out:
# Khoor, Sbwkrq!
