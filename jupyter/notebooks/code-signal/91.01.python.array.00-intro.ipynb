# %% [markdown]
# # Manipulating Arrays to Find Opposite Element Pairs

# %% [markdown]
# ## Introduction
#
# References:
# - https://codesignal.com/learn/courses/revisiting-python-essentials
# - https://codesignal.com/learn/course/91/unit/1

# %% [markdown]
# - We're going to learn about accessing and manipulating elements in Python arrays. This task provides an excellent opportunity to refine your array-handling skills in Python.
# - I am excited to guide you through an intriguing task involving arrays: pairing up 'opposite' elements.

# %% [markdown]
# ## Task
#
# Our task is to form pairs of 'opposite' elements in a given array of integers. In an array of n elements, we view the first and last elements as 'opposite', the second and second last elements as 'opposite', and so on. If the array length is odd, the middle element is its own 'opposite'.
#
# You are provided with an array of n integers, with n ranging from 1 to 100, inclusive. The task necessitates that you return an array of tuples, where each tuple comprises a pair of an element and its 'opposite' element.
#
# For example, for numbers = [1, 2, 3, 4, 5, 6, 7], the output should be [(1, 7), (2, 6), (3, 5), (4, 4), (5, 3), (6, 2), (7, 1)]

# %% [markdown]
# ## Steps
#
# Solution Building: Step 1
# - Before we start writing code, let's familiarize ourselves with how to access the elements of an array in Python.
# - In Python, the i-th element of an array numbers can be accessed as numbers[i], with the index starting from 0.
# - Consequently, the first element can be accessed using numbers[0], the second using numbers[1], and so forth, up to numbers[len(numbers) - 1] for the last element.
#
# Solution Building: Step 2
# - The 'opposite' of the i-th element of the array is the numbers[len(numbers) - i - 1]-th element.
# - To visualize this, imagine that you are standing at the start of a line and your friend is at the end of the line, with both of you being 'opposites'.
# - So, the opposite element for numbers[0] is numbers[len(numbers) - 0 - 1]
# - The opposite to numbers[1] is numbers[len(numbers) - 1 - 1], and so on.
# - We begin by initializing an empty list in which we will store our 'opposite' pairs and by calculating the array's length for later use.
#
# Solution Building: Step 3
# - Next, we loop over all elements in our array.
# - Within our loop, we create a tuple for each pair of 'opposite' elements described in step 2.
# - This pair includes the i-th element and the n - i - 1-th element.
# - We then append this tuple to our result list. Here's the final version of our function:

# %%
def solution(numbers):
    # Step 2
    result = []
    n = len(numbers)
    # Step 3
    for i in range(n):
        next_pair = (numbers[i], numbers[n - i - 1])
        result.append(next_pair)
    return result

print(solution([1, 2, 3, 4, 5, 6, 7]))
# Out:
# [(1, 7), (2, 6), (3, 5), (4, 4), (5, 3), (6, 2), (7, 1)]
