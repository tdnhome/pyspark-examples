# %% [markdown]
# # Looping in Python: Conditional Looping, Break, and Continue

# %% [markdown]
# ## Introduction
#
# References:
# - https://codesignal.com/learn/courses/revisiting-python-essentials
# - https://codesignal.com/learn/course/90/unit/4

# %% [markdown]
# What You'll Learn
#
# We're exploring Python's special instructions: Conditional Looping, along with the break and continue statements.
# - As we know, loops enable code execution multiple times.
# - Conditional looping, enhanced with break and continue, bolsters loop control, leading to flexible, efficient code.

# %% [markdown]
# ## The 'if'...'elif'...'else' Statement
#
# - Python's - if statement sets condition-based actions for our code.
# - We can also evaluate multiple conditions using elif. In other words, "If the previous condition isn't true, then check this one":

# %%
temperature = 75

if temperature > 80:
    print("It's hot outside!") # Prints if temperature is over 80.
elif temperature > 60:
    print("The weather is nice.") # Prints if temperature is between 61 and 80.
else:
    print("It might be cold outside.") # Prints if temperature is 60 or below.
# Out:
# The weather is nice.

# %% [markdown]
# ## The 'break' Statement
#
# - We use the break statement whenever we want to exit a loop prematurely once a condition is met.

# %%
numbers = [1, 3, 7, 9, 12, 15]

for number in numbers:
    if number % 2 == 0:
        print("The first even number is:", number) # Prints the first even number.
        break # Stops the loop after printing the first even number.
    print("Number:", number)
# Out:
# Number: 1
# Number: 3
# Number: 7
# Number: 9
# The first even number is: 12

# %% [markdown]
# ## The 'continue' Statement
#
# The continue statement bypasses the rest of the loop code for the current iteration only

# %%
for i in range(4):
    if i == 2:
        continue # Skips the print command for '2'.
    print(i) # Prints the current number
# Out:
# 0
# 1
# 3

# %% [markdown]
# ## Use-case with a For Loop
#
# By combining the tools we've learned so far, we can write more flexible loops.

# %%
names = ["Alice", "Bob", "Charlie", "David"]

for name in names:
    if name == "Charlie":
        print("Found Charlie!") # Prints when 'Charlie' is found.
        break # Stops the loop after finding Charlie.
    else:
        print(f"{name} is not Charlie")
# Out:
# Alice is not Charlie
# Bob is not Charlie
# Found Charlie!

# %% [markdown]
# ## Practice
#
# Well done! You are now more familiar with Python's if statement, break and continue statements, and their applications with loops. It's time to refine your learning with the upcoming practice exercises. Happy coding!
#
# - https://codesignal.com/learn/course/90/unit/4/practice/1
# - https://codesignal.com/learn/course/90/unit/4/practice/2
# - https://codesignal.com/learn/course/90/unit/4/practice/3
# - https://codesignal.com/learn/course/90/unit/4/practice/4
# - https://codesignal.com/learn/course/90/unit/4/practice/5

# %%
# List of numbers
numbers = [1, 2, 3, 4, 5]
total = 0
# `num` is each number in `numbers`
for num in numbers:
    total += num # add each number in the list
print(total) # prints the total sum
# Out:
# 15
