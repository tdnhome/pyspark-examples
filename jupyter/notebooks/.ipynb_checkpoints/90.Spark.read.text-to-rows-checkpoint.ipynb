# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

def mapper(line):
    fields = line.split(',')
    return Row(ID=int(fields[0]), name=str(fields[1].encode("utf-8")), \
               age=int(fields[2]), numFriends=int(fields[3]))

lines = spark.sparkContext.textFile("fakefriends.csv")
people = lines.map(mapper)

# Infer the schema, and register the DataFrame as a table.
schemaPeople = spark.createDataFrame(people).cache()
schemaPeople.createOrReplaceTempView("people")

# SQL can be run over DataFrames that have been registered as a table. 
# spark.sql("select ...") returns a new DataFrame
teenagers = spark.sql("SELECT * FROM people WHERE age >= 13 AND age <= 19")
teenagers.show(5)

# The results of SQL queries are RDDs and support all the normal RDD operations.
for teen in teenagers.collect():
  print(teen)

# We can also use functions instead of SQL queries:
schemaPeople.groupBy("age").count().orderBy("age").show(5)

spark.stop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 17
#      13 people = lines.map(mapper)
#      15 # Infer the schema, and register the DataFrame as a table.
#      16 #schemaPeople = spark.createDataFrame(people).cache()
# ---> 17 schemaPeople.createOrReplaceTempView("people")
#      19 # SQL can be run over DataFrames that have been registered as a table.
#      20 # spark.sql("select ...") returns a new DataFrame
#      21 teenagers = spark.sql("SELECT * FROM people WHERE age >= 13 AND age <= 19")
#
# AttributeError: 'PipelinedRDD' object has no attribute 'createOrReplaceTempView'
