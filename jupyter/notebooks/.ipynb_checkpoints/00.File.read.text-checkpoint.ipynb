# %% [markdown]
# ## File hanling
#
# Reference: https://github.com/Asabeneh/30-Days-Of-Python/blob/master/19_Day_File_handling/19_file_handling.md
#
# ### Syntax
# open('filename', mode) # mode(r, a, w, x, t,b)  could be to read, write, update
# - "r" - Read - Default value. Opens a file for reading, it returns an error if the file does not exist
# - "a" - Append - Opens a file for appending, creates the file if it does not exist
# - "w" - Write - Opens a file for writing, creates the file if it does not exist
# - "x" - Create - Creates the specified file, returns an error if the file exists
# - "t" - Text - Default value. Text mode
# - "b" - Binary - Binary mode (e.g. images)

# %% [markdown]
# ### File open for reading without using 'with' statement
#
# Without using 'with' statement, you need to close the file

# %%
print("File Handling: https://www.geeksforgeeks.org/python/file-handling-python")
file = open("text.txt", "r")
content = file.read()
print(content)
file.close()
# Out:
# File Handling: https://www.geeksforgeeks.org/python/file-handling-python
# To be or
# not to be
# that is
# the question

# %% [markdown]
# ### File open for reading with try... block
# Better with try... block

# %%
# Better with try... block
try:
    file = open("text.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError as e:
    print("Error:", e)
finally:
    file.close()
# Out:
# To be or
# not to be
# that is
# the question

# %% [markdown]
# ### File open for reading using 'with' statement
#
# Instead of manually opening and closing the file, you can use the with statement, which automatically handles closing. This reduces the risk of file corruption and resource leakage.

# %%
with open("text.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# To be or
# not to be
# that is
# the question
