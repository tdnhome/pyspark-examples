# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
sc = spark.sparkContext

lines = sc.textFile("Book.txt")

print()
print("INPUT:")
results = lines.collect()
for result in results:
    print (result)

parsedLines = lines.map(lambda x: x.upper())

print()
print ("MAPPED:")
results = parsedLines.collect()
for result in results:
    print (result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from pyspark import SparkConf, SparkContext
# ----> 3 spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
#       4 sc = spark.sparkContext
#       6 lines = sc.textFile("Book.txt")
#
# NameError: name 'SparkSession' is not defined
