# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
sc = spark.sparkContext

lines = sc.textFile("text.txt")

# Example action: count the number of lines
line_count = lines.count()
print(f"Number of lines: {line_count}")

# Example transformation: print the first few lines
first_lines = lines.take(5)
for line in first_lines:
    print(line)

# Example transformation: print the first few lines
words = lines_rdd.flatMap(lambda line: line.split(" "))
word_pairs = words.map(lambda x: (x, 1))
word_counts = word_pairs.reduceByKey(lambda a, b: a + b)

print("\nWord counts using reduceByKey on the Pair RDD:")
print(word_counts.collect())
# Out:
# Number of lines: 4
# To be or
# not to be
# that is
# the question
#
# Word counts using reduceByKey on the Pair RDD:
# [('To', 1), ('to', 1), ('question', 1), ('be', 2), ('or', 1), ('not', 1), ('that', 1), ('is', 1), ('the', 1)]
