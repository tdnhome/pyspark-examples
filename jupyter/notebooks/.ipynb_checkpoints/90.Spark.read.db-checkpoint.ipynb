# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

# JDBC connection
jdbc_url = "jdbc:mysql://localhost:3306/db-demo"

connection_properties = {
    "user": "",
    "password": "",
    "driver": "com.mysql.cj.jdbc.Driver" # Use "com.mysql.jdbc.Driver" for older versions of the connector
}


# Read from database table
table_name = "customer"
df = spark.read.jdbc(
    url=jdbc_url,
    table=table_name,
    properties=connection_properties
)

# Print the schema and show a few rows of the DataFrame
df.printSchema()
df.show(5)
# Out:
#   Cell In[3], line 9
#     jdbc:mysql://mysql:3306/db-demo
#               ^
# SyntaxError: invalid syntax
