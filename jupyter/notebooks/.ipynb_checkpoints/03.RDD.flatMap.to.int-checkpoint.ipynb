# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("SparkSQL").getOrCreate()
sc = spark.sparkContext

# Read input
data = [1, 11, 3, 6, 4 , 5, 10]
distData = sc.parallelize(data)

# Print the input
print()
print ("INPUT:")
results = distData.collect()
for result in results:
    print (result)

# Select rows 
greaterThan5 = distData.filter(lambda x: x > 5)

# Collect and print the results
print
print ("FILTER: select only numbers that are greater than 5")
results = greaterThan5.collect()
for result in results:
    print (result)
# Out:
# INPUT:
# 1
# 11
# 3
# 6
# 4
# 5
# 10
# FILTER: select only numbers that are greater than 5
# 11
# 6
# 10
