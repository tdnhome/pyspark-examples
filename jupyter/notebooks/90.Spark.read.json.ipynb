# %%
# https://sparkbyexamples.com/pyspark/pyspark-sql-with-examples
# df_csv = spark.read.csv("file.txt", header=True, inferSchema=True, delimiter=",")
# df_json = spark.read.json("file.json")
# schema = StructType([
#     StructField("name", StringType(), True),  # name, type, nullable
#     StructField("age", IntegerType(), True)
#   ])
# df_json = spark.read.json("file.json").schema(schema)

from pyspark.sql import SparkSession

# Create SparkSession
print("Spark.SQL.Example: https://sparkbyexamples.com/pyspark/pyspark-sql-with-examples")

spark = SparkSession.builder.appName("SparkByExamples").getOrCreate()

# Create DataFrame
print("spark.read.json")
df = spark.read \
          .json("simple-zipcodes.json")

print("DF.printSchema")
df.printSchema()

print("DF.show")
df.show()
# Out:
# Spark.SQL.Example: https://sparkbyexamples.com/pyspark/pyspark-sql-with-examples
# spark.read.json
# DF.printSchema
# root
#  |-- City: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- RecordNumber: long (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Zipcode: long (nullable = true)
#
# DF.show
# +-------------------+-------+------------+-----+-------+
# |               City|Country|RecordNumber|State|Zipcode|
# +-------------------+-------+------------+-----+-------+
# |        PARC PARQUE|     US|           1|   PR|    704|
# |PASEO COSTA DEL SUR|     US|           2|   PR|    704|
# |       BDA SAN LUIS|     US|          10|   PR|    709|
# |               HOLT|     US|       49347|   FL|  32564|
# |          HOMOSASSA|     US|       49348|   FL|  34487|
# |  CINGULAR WIRELESS|     US|       61391|   TX|  76166|
# |         FORT WORTH|     US|       61392|   TX|  76177|
# |           FT WORTH|     US|       61393|   TX|  76177|
# ...
